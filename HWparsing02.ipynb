# %%
from bs4 import BeautifulSoup as bs
import json
import requests
import pandas as pd

# from IPython.display import display, HTML
# from getpass import getpass

# %% [markdown]
# Для прекращения выполнения

# %%
class StopExecution(Exception):
    def _render_traceback_(self):
        pass

# %% [markdown]
# Константы и переменные

# %%
HOSTSJ = 'https://www.superjob.ru'
hostSJ_geo = '%5Bc%5D%5B0%5D=1' #На всю страну Russia
page = 1
parsed_ht = bs()
vacancies = []
name_of_vac = input('Название вакансии:')
# Out:
# Название вакансии:python

# %% [markdown]
# Отправление запроса на сервер

# %%
def request_pageSJ(page):
    if page == 1:
        page = ''
    else:
        page = f'&page={page}'
    main_link = f'{HOSTSJ}/vacancy/search/?keywords={name_of_vac}&geo{hostSJ_geo}{page}'
    print(main_link)
    try:
        req = requests.get(main_link).text
    except Exception:
        print(f'При подключении {main_link} возникла ошибка.')
        raise StopExecution
    parsed_ht.global = bs(req,'lxml')
    print(f'Запрос {HOSTSJ}, страницы {page} без ошибок')
# Out:
#   File "<ipython-input-88-2539502b379d>", line 13
#     parsed_ht.global = bs(req,'lxml')
#                    ^
# SyntaxError: invalid syntax

# %%
request_pageSJ(page)
# Out:
# https://www.superjob.ru/vacancy/search/?keywords=python&geo%5Bc%5D%5B0%5D=1
# Запрос https://www.superjob.ru, страницы  без ошибок

# %%
while parsed_ht.find('a', {'class': 'icMQ_ _1_Cht _3ze9n f-test-button-dalshe f-test-link-dalshe'}).text == 'дальше':
    parseSJ(parsed_ht)
    page += 1
    request_pageSJ(page)
else:
    page = 1
    parseSJ(parsed_ht)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-86-a95a051006bc> in <module>
# ----> 1 while parsed_ht.find('a', {'class': 'icMQ_ _1_Cht _3ze9n f-test-button-dalshe f-test-link-dalshe'}).text == 'дальше':
#       2     parseSJ(parsed_ht)
#       3     page += 1
#       4     request_pageSJ(page)
#       5 else:
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
df = pd.DataFrame(vacancies)
df
# Out:
#             site                                        position  salary_min  \
# 0    superjob.ru                              Разработчик Python           0
# 1    superjob.ru                              Программист Python           0
# 2    superjob.ru                       Программист Perl / Python       45000
# 3    superjob.ru                                 Аналитик python           0
# 4    superjob.ru                           Программист на python           0
# ..           ...                                             ...         ...
# 280  superjob.ru  Ведущий системный администратор Linux (Zabbix)           0
# 281  superjob.ru             Администратор баз данных PostgreSQL           0
# 282  superjob.ru                           Web-разработчик React           0
# 283  superjob.ru            Тестировщик программного обеспечения           0
# 284  superjob.ru    Специалист по автоматизации бизнес-процессов           0
#
#      salary_max             salary  \
# 0             0  По договорённости
# 1             0  По договорённости
# 2         45000  45 000 — 45 000 ₽
# 3             0  По договорённости
# 4             0  По договорённости
# ..          ...                ...
# 280           0  По договорённости
# 281           0          150 000 ₽
# 282           0  По договорённости
# 283           0  По договорённости
# 284           0  По договорённости
#
#                                                   from             city  \
# 0                                            Цифрасофт           Ижевск
# 1                                 Кадровое решение СПб  Санкт-Петербург
# 2                                               Дом.ru            Пермь
# 3                                 Правительство Москвы           Москва
# 4                                                НТИМИ           Москва
# ..                                                 ...              ...
# 280  Филиал ФКУ Налог-Сервис ФНС России по ЦОД в г....           Москва
# 281  Филиал ФКУ Налог-Сервис ФНС России по ЦОД в г....           Москва
# 282                                               КРИТ           Ижевск
# 283                               Правительство Москвы           Москва
# 284                                           Netbynet          Воронеж
#
#                                                   link
# 0    https://www.superjob.ru/vakansii/razrabotchik-...
# 1    https://www.superjob.ru/vakansii/programmist-p...
# 2    https://www.superjob.ru/vakansii/programmist-p...
# 3    https://www.superjob.ru/vakansii/analitik-pyth...
# 4    https://www.superjob.ru/vakansii/programmist-n...
# ..                                                 ...
# 280  https://www.superjob.ru/vakansii/veduschij-sis...
# 281  https://www.superjob.ru/vakansii/administrator...
# 282  https://www.superjob.ru/vakansii/web-razrabotc...
# 283  https://www.superjob.ru/vakansii/testirovschik...
# 284  https://www.superjob.ru/vakansii/specialist-po...
#
# [285 rows x 8 columns]

# %%
def salary_eject(salary):
    if not salary or 'договорённости' in salary:
        return 0, 0
    salary = ''.join(salary.split())
    if 'от' in salary:
        salary = salary.replace('от', '').replace('₽', '')
        return int(salary), 0
    if 'до' in salary:
        salary = salary.replace('до', '').replace('₽', '')
        return 0, int(salary)
    if '—' in salary:
        salary = salary.replace('₽', '')
        salary = salary.split('—')
        return int(salary[0]), int(salary[1])
    return (0, 0)

# %%
def parseSJ(parsed_html):
    div_block = parsed_html.find_all('div', {'class':'_3syPg _3P0J7 _9_FPy'})
    for div in div_block:
        vac_data={}
        try:
            a_all = div.find_all('a')
            # position
            name_div = div.find('div', {'class': '_3mfro CuJz5 PlM3e _2JVkc _3LJqf'}).text
            # salary
            summ_span = div.find('span', {'class': 'f-test-text-company-item-salary'}).text
            # link
            href_a = a_all[0]['href']
            href_link = HOSTSJ + href_a
            # or from who
            comp = a_all[1].getText()
            # data
            time_div = div.find('span', {'class': '_3mfro _9fXTd _2JVkc _3e53o _3Ll36'})
            # city
            town_div = time_div.findNextSiblings()[0].text
            vac_data['site'] = 'superjob.ru'
            vac_data['position'] = name_div
            salary = salary_eject(summ_span)
            str_salary = summ_span.replace('\xa0',' ')
            #             sum_min, sum_max = salary_sj(str_salary)
            vac_data['salary_min'] = salary[0]
            vac_data['salary_max'] = salary[1]
            vac_data['salary'] = str_salary
            vac_data['from'] = comp
            vac_data['city'] = town_div
            #vac_data['time'] = time_div.getText()
            vac_data['link'] = href_link
            vacancies.append(vac_data)
        except Exception  as e:
            print(e)

# %%
# Out:
# list index out of range
#            site                                        position  salary_min  \
# 0   superjob.ru                              Разработчик Python           0
# 1   superjob.ru                              Программист Python           0
# 2   superjob.ru                       Программист Perl / Python       45000
# 3   superjob.ru                                 Аналитик python           0
# 4   superjob.ru                           Программист на python           0
# 5   superjob.ru           Backend разработчик (Python / Django)       80000
# 6   superjob.ru                                  Тестировщик НТ           0
# 7   superjob.ru                       Разработчик Витрин Данных           0
# 8   superjob.ru                       Разработчик Oracle PL/SQL           0
# 9   superjob.ru   Администратор тестовых сред (ведущий инженер)           0
# 10  superjob.ru                            Финансовый контролер           0
# 11  superjob.ru                       Тестировщик ПО / Аналитик       80000
# 12  superjob.ru                    Старший back-end разработчик      150000
# 13  superjob.ru                             Инженер-программист       40000
# 14  superjob.ru  Ведущий системный администратор Linux (Zabbix)           0
# 15  superjob.ru             Администратор баз данных PostgreSQL           0
# 16  superjob.ru                           Web-разработчик React           0
# 17  superjob.ru            Тестировщик программного обеспечения           0
# 18  superjob.ru    Специалист по автоматизации бизнес-процессов           0
#
#     salary_max              salary  \
# 0            0   По договорённости
# 1            0   По договорённости
# 2        45000   45 000 — 45 000 ₽
# 3            0   По договорённости
# 4            0   По договорённости
# 5       190000  80 000 — 190 000 ₽
# 6            0   По договорённости
# 7            0   По договорённости
# 8            0   По договорённости
# 9            0   По договорённости
# 10           0   По договорённости
# 11       80000   80 000 — 80 000 ₽
# 12           0        от 150 000 ₽
# 13           0         от 40 000 ₽
# 14           0   По договорённости
# 15           0           150 000 ₽
# 16           0   По договорённости
# 17           0   По договорённости
# 18           0   По договорённости
#
#                                                  from  \
# 0                                           Цифрасофт
# 1                                Кадровое решение СПб
# 2                                              Дом.ru
# 3                                Правительство Москвы
# 4                                               НТИМИ
# 5                                     СтройУчетСервис
# 6                                     Сбербанк России
# 7                                     Сбербанк России
# 8                                       РЕСО-Гарантия
# 9                                     Сбербанк России
# 10                                    Сбербанк России
# 11                             ОСГ Рекордз Менеджмент
# 12                                     ВИЗАВИ Консалт
# 13                                          НИИСИ РАН
# 14  Филиал ФКУ Налог-Сервис ФНС России по ЦОД в г....
# 15  Филиал ФКУ Налог-Сервис ФНС России по ЦОД в г....
# 16                                               КРИТ
# 17                               Правительство Москвы
# 18                                           Netbynet
#
#                            city  \
# 0                        Ижевск
# 1               Санкт-Петербург
# 2                         Пермь
# 3                        Москва
# 4                        Москва
# 5                        Москва
# 6                        Москва
# 7                        Москва
# 8   Москва,Нахимовский проспект
# 9               Санкт-Петербург
# 10              Нижний Новгород
# 11                       Москва
# 12                      Вологда
# 13           Москва,Профсоюзная
# 14                       Москва
# 15                       Москва
# 16                       Ижевск
# 17                       Москва
# 18                      Воронеж
#
#                                                  link
# 0   https://www.superjob.ru/vakansii/razrabotchik-...
# 1   https://www.superjob.ru/vakansii/programmist-p...
# 2   https://www.superjob.ru/vakansii/programmist-p...
# 3   https://www.superjob.ru/vakansii/analitik-pyth...
# 4   https://www.superjob.ru/vakansii/programmist-n...
# 5   https://www.superjob.ru/vakansii/backend-razra...
# 6   https://www.superjob.ru/vakansii/testirovschik...
# 7   https://www.superjob.ru/vakansii/razrabotchik-...
# 8   https://www.superjob.ru/vakansii/razrabotchik-...
# 9   https://www.superjob.ru/vakansii/administrator...
# 10  https://www.superjob.ru/vakansii/finansovyj-ko...
# 11  https://www.superjob.ru/vakansii/testirovschik...
# 12  https://www.superjob.ru/vakansii/starshij-back...
# 13  https://www.superjob.ru/vakansii/inzhener-prog...
# 14  https://www.superjob.ru/vakansii/veduschij-sis...
# 15  https://www.superjob.ru/vakansii/administrator...
# 16  https://www.superjob.ru/vakansii/web-razrabotc...
# 17  https://www.superjob.ru/vakansii/testirovschik...
# 18  https://www.superjob.ru/vakansii/specialist-po...
